# %% [markdown]
# # Explore And Analyze How the Data Looks
# **This notebook is to check how messy the data is so proper data cleaning methods can be applied.**

# %% [markdown]
# ### Import libraries and config to load the dataset

# %%
import os
import sys
import pandas as pd
import numpy as np

sys.path.append(os.path.abspath('..'))

from config import DATA_DIR,RAW_DATA_PATH

# %%
df = pd.read_csv(RAW_DATA_PATH,encoding='latin1')

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Check the each column data types, their missing values and their statistical data

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  str
#  1   StockCode    541909 non-null  str
#  2   Description  540455 non-null  str
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  str
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 33.1 MB

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.describe().round(2)
# Out:
#         Quantity                 InvoiceDate  UnitPrice  CustomerID
# count  397884.00                      397884  397884.00   397884.00
# mean       12.99  2011-07-10 23:41:23.511023       3.12    15294.42
# min         1.00         2010-12-01 08:26:00       0.00    12346.00
# 25%         2.00         2011-04-07 11:12:00       1.25    13969.00
# 50%         6.00         2011-07-31 14:39:00       1.95    15159.00
# 75%        12.00         2011-10-20 14:33:00       3.75    16795.00
# max     80995.00         2011-12-09 12:50:00    8142.75    18287.00
# std       179.33                         NaN      22.10     1713.14

# %%
df = df.dropna(subset=["CustomerID"],axis=0)

df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

df = df[(df["Quantity"]>0) & (df["UnitPrice"]>0)]

# %%
df.describe().round(2)
# Out:
#         Quantity                 InvoiceDate  UnitPrice  CustomerID
# count  397884.00                      397884  397884.00   397884.00
# mean       12.99  2011-07-10 23:41:23.511023       3.12    15294.42
# min         1.00         2010-12-01 08:26:00       0.00    12346.00
# 25%         2.00         2011-04-07 11:12:00       1.25    13969.00
# 50%         6.00         2011-07-31 14:39:00       1.95    15159.00
# 75%        12.00         2011-10-20 14:33:00       3.75    16795.00
# max     80995.00         2011-12-09 12:50:00    8142.75    18287.00
# std       179.33                         NaN      22.10     1713.14
